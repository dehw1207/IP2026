# %%
tu = (23, 'abc', 4.56, (2,3), 'def') # tu[1] = 45 이런식으로 바꾸는 게 안 됨

# %%
print(tu)
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
li = ["abc", 34, 4.34, 23] # 값 바꾸기 가능

# %%
print(li) #여기까지 27페이지
# Out:
# ['abc', 34, 4.34, 23]

# %%
li[1]
# Out:
# 34

# %%
tu[1] #여기까지 28페이지
# Out:
# 'abc'

# %%
li[-1]
# Out:
# 23

# %%
li[1:-1]
# Out:
# [34, 4.34]

# %%
tu[:2] #여기까지 29~31페이지
# Out:
# (23, 'abc')

# %%
list1 = [1, 2, 3]

# %%
list2 = list1

list2
# Out:
# [1, 2, 3]

# %%
list2[1] = 99

# %%
list2
# Out:
# [1, 99, 3]

# %%
list1 #list2가 list1 주소를 가져간 것이기 때문에 list2에 있는 값을 변경해도 list1도 같이 변경이 됨
      #list2만 변경하기 위해서는 list2 = list1[:](하드카피) 명령어를 사용해야 함
# Out:
# [1, 99, 3]

# %%
list2 = list1[:]

# %%
list2[1] = 22

list2
# Out:
# [1, 22, 3]

# %%
list1 #여기까지 32페이지
# Out:
# [1, 99, 3]

# %%
t = [1, 2, 3, 5]
3 in t
# Out:
# True

# %%
3 not in t
# Out:
# False

# %%
(1, 2, 3) + (4, 5, 6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"Hello" + " " + "World" #여기까지 34페이지
# Out:
# 'Hello World'
