# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('open_cv.png')
res1 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_LINEAR)
res2 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_AREA)
res3 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

# %%
cv2.namedWindow('res1')
cv2.namedWindow('res2')
cv2.namedWindow('res3')
cv2.resizeWindow('res1', rows*2, cols*2)
cv2.resizeWindow('res2', rows*2, cols*2)
cv2.resizeWindow('res3', rows*2, cols*2)
while(1):
    cv2.imshow('res1',res1)
    cv2.imshow('res2',res2) 
    cv2.imshow('res3',res3)
    if cv2.waitKey(20) & 0xff == 27:
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 8
#       6 cv2.resizeWindow('res3', rows*2, cols*2)
#       7 while(1):
# ----> 8     cv2.imshow('res1',res1)
#       9     cv2.imshow('res2',res2)
#      10     cv2.imshow('res3',res3)
#
# NameError: name 'res1' is not defined

# %%
M = np.float32([[1,0,100],[0,1,0]])
dst = cv2.warpAffine(img,M,(cols,rows))
cv2.imshow('img',img)
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Perspective Transformation

# %%
img = cv2.imread('dsu3.jpg') #중간고사에 나옴
rows,cols,ch = img.shape
pts1 = np.float32([[102,227],[702,165],[706,539],[107,495]])
pts2 = np.float32([[100,200],[700,200],[700,500],[100,500]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(900,800))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('IMG_6504.jpg') #중간고사에 나옴 ㄷ 반대방향 순서로 좌표(시계방향)
rows,cols,ch = img.shape
pts1 = np.float32([[167,189],[762,193],[810,1096],[96,1083]])
pts2 = np.float32([[200,200],[800,200],[800,1100],[200,1100]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(900,1200))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
